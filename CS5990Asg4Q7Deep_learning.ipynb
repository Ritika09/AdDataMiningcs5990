# %%
#-------------------------------------------------------------------------
# AUTHOR: Ritika
# FILENAME: DeepLearning
# SPECIFICATION: Classify fashion items
# FOR: CS 5990- Assignment #4
# TIME SPENT: 35 minutes
#-----------------------------------------------------------*/

#IMPORTANT NOTE: YOU CAN USE ANY PYTHON LIBRARY TO COMPLETE YOUR CODE.

#importing the libraries
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

def build_model(n_hidden, n_neurons_hidden, n_neurons_output, learning_rate):

    #-->add your Pyhton code here

    #Creating the Neural Network using the Sequential API
    model = keras.models.Sequential()
    model.add(keras.layers.Flatten(input_shape=[28, 28]))                                #input layer

    #iterate over the number of hidden layers to create the hidden layers:
    for hidden_layer in range(n_hidden):
        model.add(keras.layers.Dense(n_neurons_hidden, activation="relu"))                   #hidden layer with ReLU activation function

    #output layer
    model.add(keras.layers.Dense(n_neurons_output, activation="softmax"))                #output layer with one neural for each class and the softmax activation function since the classes are exclusive

    #defining the learning rate
    opt = keras.optimizers.SGD(learning_rate)

    #Compiling the Model specifying the loss function and the optimizer to use.
    model.compile(loss="sparse_categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
    return model


#To install Tensor Flow on your terminal
#python -m pip install --upgrade tensorflow

#Using Keras to Load the Dataset. Every image is represented as a 28×28 array rather than a 1D array of size 784. Moreover, the pixel intensities are represented as integers (from
#0 to 255) rather than floats (from 0.0 to 255.0).
fashion_mnist = keras.datasets.fashion_mnist
(X_train_full, y_train_full), (X_test, y_test) = fashion_mnist.load_data()

#creating a validation set and scaling the features
X_valid, X_train = X_train_full[:5000] / 255.0, X_train_full[5000:] / 255.0
y_valid, y_train = y_train_full[:5000], y_train_full[5000:]

#For Fashion MNIST, we need the list of class names to know what we are dealing with. For instance, class_names[y_train[0]] = 'Coat'
class_names = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

#Iterate here over number of hidden layers, number of neurons in each hidden layer and the learning rate.
#-->add your Pyhton code here

n_hidden = [2, 5, 10]
n_neurons = [10, 50, 100]
l_rate = [0.01, 0.05, 0.1]

for h in n_hidden:                          #looking or the best parameters w.r.t the number of hidden layers
    for n in n_neurons:                     #looking or the best parameters w.r.t the number of neurons
        for l in l_rate:                    #looking or the best parameters w.r.t the learning rate

            #build the model for each combination by calling the function:
            model = build_model(h,n,10,l)

            #To train the model
            history = model.fit(X_train, y_train, epochs=5, validation_data=(X_valid, y_valid))  #epochs = number times that the learning algorithm will work through the entire training dataset.

            #Calculate the accuracy of this neural network and store its value if it is the highest so far. To make a prediction, do:
            class_predicted = np.argmax(model.predict(X_test), axis=-1)
            #-->add your Pyhton code here
            highestAccuracy = history.history['accuracy'][-1]
            print("Highest accuracy so far: " + str(highestAccuracy))
            print("Parameters: " + "Number of Hidden Layers: " + str(h) + ",number of neurons: " + str(n) + ",learning rate: " + str(l))
            print()

#After generating all neural networks, print the summary of the best model found
#The model’s summary() method displays all the model’s layers, including each layer’s name (which is automatically generated unless you set it when creating the layer), its
#output shape (None means the batch size can be anything), and its number of parameters. Note that Dense layers often have a lot of parameters. This gives the model quite a lot of
#flexibility to fit the training data, but it also means that the model runs the risk of overfitting, especially when you do not have a lot of training data.

print(model.summary())
img_file = './model_arch.png'
tf.keras.utils.plot_model(model, to_file=img_file, show_shapes=True, show_layer_names=True)

#plotting the learning curves of the best model
pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1) # set the vertical range to [0-1]
plt.show()
# Out:
# Epoch 1/5
# 1719/1719 [==============================] - 6s 3ms/step - loss: 1.5445 - accuracy: 0.4249 - val_loss: 1.2172 - val_accuracy: 0.5666
# Epoch 2/5
# 1719/1719 [==============================] - 5s 3ms/step - loss: 1.0690 - accuracy: 0.6419 - val_loss: 0.8822 - val_accuracy: 0.6838
# Epoch 3/5
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.7898 - accuracy: 0.7246 - val_loss: 0.6784 - val_accuracy: 0.7636
# Epoch 4/5
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.6366 - accuracy: 0.7764 - val_loss: 0.5795 - val_accuracy: 0.8076
# Epoch 5/5
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.5614 - accuracy: 0.8072 - val_loss: 0.5299 - val_accuracy: 0.8234
# Highest accuracy so far: 0.807200014591217
# Parameters: Number of Hidden Layers: 2,number of neurons: 10,learning rate: 0.01
#
# Epoch 1/5
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.8010 - accuracy: 0.7059 - val_loss: 0.5635 - val_accuracy: 0.8062
# Epoch 2/5
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.5572 - accuracy: 0.8044 - val_loss: 0.5060 - val_accuracy: 0.8296
# Epoch 3/5
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.5159 - accuracy: 0.8194 - val_loss: 0.4948 - val_accuracy: 0.8230
# Epoch 4/5
# 1719/1719 [==============================] - 4s 3ms/step - loss: 0.4889 - accuracy: 0.8263 - val_loss: 0.5630 - val_accuracy: 0.7872
# Epoch 5/5
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.4682 - accuracy: 0.8331 - val_loss: 0.4440 - val_accuracy: 0.8412
# Highest accuracy so far: 0.8331272602081299
# Parameters: Number of Hidden Layers: 2,number of neurons: 10,learning rate: 0.05
#
# Epoch 1/5
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.7522 - accuracy: 0.7272 - val_loss: 0.5455 - val_accuracy: 0.8098
# Epoch 2/5
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.5092 - accuracy: 0.8169 - val_loss: 0.4469 - val_accuracy: 0.8420
# Epoch 3/5
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.4653 - accuracy: 0.8312 - val_loss: 0.4504 - val_accuracy: 0.8438
# Epoch 4/5
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.4462 - accuracy: 0.8379 - val_loss: 0.4420 - val_accuracy: 0.8460
# Epoch 5/5
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.4311 - accuracy: 0.8440 - val_loss: 0.4120 - val_accuracy: 0.8562
# Highest accuracy so far: 0.843999981880188
# Parameters: Number of Hidden Layers: 2,number of neurons: 10,learning rate: 0.1
#
# Epoch 1/5
# 1719/1719 [==============================] - 6s 3ms/step - loss: 0.8338 - accuracy: 0.7162 - val_loss: 0.6134 - val_accuracy: 0.7688
# Epoch 2/5
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.5240 - accuracy: 0.8181 - val_loss: 0.5058 - val_accuracy: 0.8164
# Epoch 3/5
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.4673 - accuracy: 0.8375 - val_loss: 0.4330 - val_accuracy: 0.8510
# Epoch 4/5
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.4376 - accuracy: 0.8473 - val_loss: 0.4268 - val_accuracy: 0.8506
# Epoch 5/5
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.4158 - accuracy: 0.8559 - val_loss: 0.4017 - val_accuracy: 0.8618
# Highest accuracy so far: 0.8558727502822876
# Parameters: Number of Hidden Layers: 2,number of neurons: 50,learning rate: 0.01
#
# Epoch 1/5
# 1719/1719 [==============================] - 6s 3ms/step - loss: 0.6052 - accuracy: 0.7848 - val_loss: 0.4458 - val_accuracy: 0.8392
# Epoch 2/5
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.4257 - accuracy: 0.8465 - val_loss: 0.4224 - val_accuracy: 0.8528
# Epoch 3/5
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3841 - accuracy: 0.8606 - val_loss: 0.3784 - val_accuracy: 0.8650
# Epoch 4/5
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3621 - accuracy: 0.8677 - val_loss: 0.4313 - val_accuracy: 0.8436
# Epoch 5/5
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3432 - accuracy: 0.8757 - val_loss: 0.3371 - val_accuracy: 0.8780
# Highest accuracy so far: 0.8757091164588928
# Parameters: Number of Hidden Layers: 2,number of neurons: 50,learning rate: 0.05
#
# Epoch 1/5
# 1719/1719 [==============================] - 6s 3ms/step - loss: 0.5788 - accuracy: 0.7890 - val_loss: 0.4261 - val_accuracy: 0.8440
# Epoch 2/5
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.4206 - accuracy: 0.8467 - val_loss: 0.3634 - val_accuracy: 0.8716
# Epoch 3/5
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3784 - accuracy: 0.8602 - val_loss: 0.4122 - val_accuracy: 0.8490
# Epoch 4/5
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3510 - accuracy: 0.8707 - val_loss: 0.3638 - val_accuracy: 0.8648
# Epoch 5/5
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3342 - accuracy: 0.8758 - val_loss: 0.3382 - val_accuracy: 0.8770
# Highest accuracy so far: 0.8757818341255188
# Parameters: Number of Hidden Layers: 2,number of neurons: 50,learning rate: 0.1
#
# Epoch 1/5
# 1719/1719 [==============================] - 7s 3ms/step - loss: 0.7576 - accuracy: 0.7506 - val_loss: 0.5572 - val_accuracy: 0.8018
# Epoch 2/5
# 1719/1719 [==============================] - 6s 3ms/step - loss: 0.5050 - accuracy: 0.8239 - val_loss: 0.4490 - val_accuracy: 0.8452
# Epoch 3/5
# 1719/1719 [==============================] - 6s 3ms/step - loss: 0.4563 - accuracy: 0.8394 - val_loss: 0.4271 - val_accuracy: 0.8514
# Epoch 4/5
# 1719/1719 [==============================] - 6s 3ms/step - loss: 0.4288 - accuracy: 0.8493 - val_loss: 0.4359 - val_accuracy: 0.8470
# Epoch 5/5
# 1719/1719 [==============================] - 6s 3ms/step - loss: 0.4075 - accuracy: 0.8560 - val_loss: 0.3876 - val_accuracy: 0.8698
# Highest accuracy so far: 0.8559636473655701
# Parameters: Number of Hidden Layers: 2,number of neurons: 100,learning rate: 0.01
#
# Epoch 1/5
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.5795 - accuracy: 0.7961 - val_loss: 0.4825 - val_accuracy: 0.8284
# Epoch 2/5
# 1719/1719 [==============================] - 6s 4ms/step - loss: 0.4122 - accuracy: 0.8507 - val_loss: 0.4051 - val_accuracy: 0.8544
# Epoch 3/5
# 1719/1719 [==============================] - 6s 4ms/step - loss: 0.3717 - accuracy: 0.8647 - val_loss: 0.3666 - val_accuracy: 0.8672
# Epoch 4/5
# 1719/1719 [==============================] - 6s 4ms/step - loss: 0.3492 - accuracy: 0.8707 - val_loss: 0.3574 - val_accuracy: 0.8656
# Epoch 5/5
# 1719/1719 [==============================] - 6s 4ms/step - loss: 0.3303 - accuracy: 0.8768 - val_loss: 0.3295 - val_accuracy: 0.8810
# Highest accuracy so far: 0.876836359500885
# Parameters: Number of Hidden Layers: 2,number of neurons: 100,learning rate: 0.05
#
# Epoch 1/5
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.5492 - accuracy: 0.8002 - val_loss: 0.3999 - val_accuracy: 0.8606
# Epoch 2/5
# 1719/1719 [==============================] - 6s 4ms/step - loss: 0.3996 - accuracy: 0.8524 - val_loss: 0.4337 - val_accuracy: 0.8406
# Epoch 3/5
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.3621 - accuracy: 0.8652 - val_loss: 0.3955 - val_accuracy: 0.8438
# Epoch 4/5
# 1719/1719 [==============================] - 6s 4ms/step - loss: 0.3363 - accuracy: 0.8731 - val_loss: 0.3999 - val_accuracy: 0.8534
# Epoch 5/5
# 1719/1719 [==============================] - 6s 4ms/step - loss: 0.3192 - accuracy: 0.8806 - val_loss: 0.3712 - val_accuracy: 0.8626
# Highest accuracy so far: 0.880618155002594
# Parameters: Number of Hidden Layers: 2,number of neurons: 100,learning rate: 0.1
#
# Epoch 1/5
# 1719/1719 [==============================] - 6s 3ms/step - loss: 1.6155 - accuracy: 0.3790 - val_loss: 1.0495 - val_accuracy: 0.6428
# Epoch 2/5
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.8240 - accuracy: 0.7014 - val_loss: 0.6831 - val_accuracy: 0.7560
# Epoch 3/5
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.6183 - accuracy: 0.7775 - val_loss: 0.6179 - val_accuracy: 0.7854
# Epoch 4/5
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.5528 - accuracy: 0.8062 - val_loss: 0.5228 - val_accuracy: 0.8168
# Epoch 5/5
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.5190 - accuracy: 0.8175 - val_loss: 0.4917 - val_accuracy: 0.8326
# Highest accuracy so far: 0.8174909353256226
# Parameters: Number of Hidden Layers: 5,number of neurons: 10,learning rate: 0.01
#
# Epoch 1/5
# 1719/1719 [==============================] - 6s 3ms/step - loss: 0.9903 - accuracy: 0.6355 - val_loss: 0.6193 - val_accuracy: 0.7678
# Epoch 2/5
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.5728 - accuracy: 0.7959 - val_loss: 0.4977 - val_accuracy: 0.8238
# Epoch 3/5
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.5084 - accuracy: 0.8196 - val_loss: 0.4548 - val_accuracy: 0.8418
# Epoch 4/5
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.4752 - accuracy: 0.8315 - val_loss: 0.4567 - val_accuracy: 0.8388
# Epoch 5/5
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.4567 - accuracy: 0.8370 - val_loss: 0.6056 - val_accuracy: 0.7870
# Highest accuracy so far: 0.8370181918144226
# Parameters: Number of Hidden Layers: 5,number of neurons: 10,learning rate: 0.05
#
# Epoch 1/5
# 1719/1719 [==============================] - 6s 3ms/step - loss: 0.9508 - accuracy: 0.6308 - val_loss: 0.5978 - val_accuracy: 0.7846
# Epoch 2/5
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.5881 - accuracy: 0.7837 - val_loss: 0.5248 - val_accuracy: 0.8138
# Epoch 3/5
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.5163 - accuracy: 0.8156 - val_loss: 0.4754 - val_accuracy: 0.8268
# Epoch 4/5
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.4809 - accuracy: 0.8282 - val_loss: 0.4369 - val_accuracy: 0.8490
# Epoch 5/5
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.4606 - accuracy: 0.8361 - val_loss: 0.4548 - val_accuracy: 0.8370
# Highest accuracy so far: 0.8361454606056213
# Parameters: Number of Hidden Layers: 5,number of neurons: 10,learning rate: 0.1
#
# Epoch 1/5
# 1719/1719 [==============================] - 8s 4ms/step - loss: 1.0283 - accuracy: 0.6479 - val_loss: 0.6575 - val_accuracy: 0.7684
# Epoch 2/5
# 1719/1719 [==============================] - 6s 4ms/step - loss: 0.5477 - accuracy: 0.8049 - val_loss: 0.4707 - val_accuracy: 0.8358
# Epoch 3/5
# 1719/1719 [==============================] - 6s 4ms/step - loss: 0.4781 - accuracy: 0.8295 - val_loss: 0.4507 - val_accuracy: 0.8374
# Epoch 4/5
# 1719/1719 [==============================] - 6s 4ms/step - loss: 0.4385 - accuracy: 0.8425 - val_loss: 0.4022 - val_accuracy: 0.8598
# Epoch 5/5
# 1719/1719 [==============================] - 6s 3ms/step - loss: 0.4120 - accuracy: 0.8515 - val_loss: 0.3887 - val_accuracy: 0.8618
# Highest accuracy so far: 0.8514545559883118
# Parameters: Number of Hidden Layers: 5,number of neurons: 50,learning rate: 0.01
#
# Epoch 1/5
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.6592 - accuracy: 0.7566 - val_loss: 0.4522 - val_accuracy: 0.8386
# Epoch 2/5
# 1719/1719 [==============================] - 6s 3ms/step - loss: 0.4398 - accuracy: 0.8394 - val_loss: 0.4242 - val_accuracy: 0.8478
# Epoch 3/5
# 1719/1719 [==============================] - 6s 3ms/step - loss: 0.3962 - accuracy: 0.8548 - val_loss: 0.3617 - val_accuracy: 0.8686
# Epoch 4/5
# 1719/1719 [==============================] - 6s 3ms/step - loss: 0.3695 - accuracy: 0.8633 - val_loss: 0.3449 - val_accuracy: 0.8756
# Epoch 5/5
# 1719/1719 [==============================] - 6s 3ms/step - loss: 0.3489 - accuracy: 0.8727 - val_loss: 0.3414 - val_accuracy: 0.8804
# Highest accuracy so far: 0.8726545572280884
# Parameters: Number of Hidden Layers: 5,number of neurons: 50,learning rate: 0.05
#
# Epoch 1/5
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.6594 - accuracy: 0.7537 - val_loss: 0.4649 - val_accuracy: 0.8406
# Epoch 2/5
# 1719/1719 [==============================] - 6s 3ms/step - loss: 0.4366 - accuracy: 0.8389 - val_loss: 0.3961 - val_accuracy: 0.8598
# Epoch 3/5
# 1719/1719 [==============================] - 6s 3ms/step - loss: 0.3927 - accuracy: 0.8550 - val_loss: 0.3699 - val_accuracy: 0.8686
# Epoch 4/5
# 1719/1719 [==============================] - 6s 4ms/step - loss: 0.3704 - accuracy: 0.8613 - val_loss: 0.3969 - val_accuracy: 0.8514
# Epoch 5/5
# 1719/1719 [==============================] - 6s 4ms/step - loss: 0.3521 - accuracy: 0.8696 - val_loss: 0.3688 - val_accuracy: 0.8650
# Highest accuracy so far: 0.8696181774139404
# Parameters: Number of Hidden Layers: 5,number of neurons: 50,learning rate: 0.1
#
# Epoch 1/5
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.9061 - accuracy: 0.6773 - val_loss: 0.5473 - val_accuracy: 0.8038
# Epoch 2/5
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.5082 - accuracy: 0.8199 - val_loss: 0.4503 - val_accuracy: 0.8420
# Epoch 3/5
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.4479 - accuracy: 0.8394 - val_loss: 0.4123 - val_accuracy: 0.8544
# Epoch 4/5
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.4122 - accuracy: 0.8525 - val_loss: 0.3900 - val_accuracy: 0.8608
# Epoch 5/5
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.3873 - accuracy: 0.8596 - val_loss: 0.4042 - val_accuracy: 0.8578
# Highest accuracy so far: 0.8596000075340271
# Parameters: Number of Hidden Layers: 5,number of neurons: 100,learning rate: 0.01
#
# Epoch 1/5
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.6434 - accuracy: 0.7609 - val_loss: 0.5432 - val_accuracy: 0.8060
# Epoch 2/5
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.4226 - accuracy: 0.8443 - val_loss: 0.4059 - val_accuracy: 0.8520
# Epoch 3/5
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.3791 - accuracy: 0.8600 - val_loss: 0.3586 - val_accuracy: 0.8704
# Epoch 4/5
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.3507 - accuracy: 0.8702 - val_loss: 0.3492 - val_accuracy: 0.8730
# Epoch 5/5
# 1719/1719 [==============================] - 2703s 2s/step - loss: 0.3324 - accuracy: 0.8759 - val_loss: 0.3285 - val_accuracy: 0.8824
# Highest accuracy so far: 0.8758545517921448
# Parameters: Number of Hidden Layers: 5,number of neurons: 100,learning rate: 0.05
#
# Epoch 1/5
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.6123 - accuracy: 0.7717 - val_loss: 0.5529 - val_accuracy: 0.7764
# Epoch 2/5
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.4135 - accuracy: 0.8473 - val_loss: 0.3765 - val_accuracy: 0.8620
# Epoch 3/5
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.3724 - accuracy: 0.8606 - val_loss: 0.3536 - val_accuracy: 0.8706
# Epoch 4/5
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.3447 - accuracy: 0.8711 - val_loss: 0.4313 - val_accuracy: 0.8362
# Epoch 5/5
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.3246 - accuracy: 0.8788 - val_loss: 0.3757 - val_accuracy: 0.8682
# Highest accuracy so far: 0.8787636160850525
# Parameters: Number of Hidden Layers: 5,number of neurons: 100,learning rate: 0.1
#
# Epoch 1/5
# 1719/1719 [==============================] - 8s 4ms/step - loss: 2.2603 - accuracy: 0.1670 - val_loss: 1.9885 - val_accuracy: 0.2042
# Epoch 2/5
# 1719/1719 [==============================] - 6s 4ms/step - loss: 1.7169 - accuracy: 0.2788 - val_loss: 1.5536 - val_accuracy: 0.3508
# Epoch 3/5
# 1719/1719 [==============================] - 6s 4ms/step - loss: 1.3191 - accuracy: 0.4436 - val_loss: 1.0740 - val_accuracy: 0.5902
# Epoch 4/5
# 1719/1719 [==============================] - 6s 4ms/step - loss: 0.9628 - accuracy: 0.6185 - val_loss: 0.8266 - val_accuracy: 0.6948
# Epoch 5/5
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.8579 - accuracy: 0.6725 - val_loss: 0.7829 - val_accuracy: 0.7106
# Highest accuracy so far: 0.6724727153778076
# Parameters: Number of Hidden Layers: 10,number of neurons: 10,learning rate: 0.01
#
# Epoch 1/5
# 1719/1719 [==============================] - 8s 4ms/step - loss: 1.4018 - accuracy: 0.4441 - val_loss: 0.7768 - val_accuracy: 0.6954
# Epoch 2/5
# 1719/1719 [==============================] - 6s 4ms/step - loss: 0.7606 - accuracy: 0.7190 - val_loss: 0.6084 - val_accuracy: 0.7832
# Epoch 3/5
# 1719/1719 [==============================] - 6s 4ms/step - loss: 0.6324 - accuracy: 0.7657 - val_loss: 0.6367 - val_accuracy: 0.7752
# Epoch 4/5
# 1719/1719 [==============================] - 6s 4ms/step - loss: 0.6021 - accuracy: 0.7797 - val_loss: 0.5730 - val_accuracy: 0.8042
# Epoch 5/5
# 1719/1719 [==============================] - 6s 3ms/step - loss: 0.5719 - accuracy: 0.7890 - val_loss: 0.5497 - val_accuracy: 0.8016
# Highest accuracy so far: 0.7889636158943176
# Parameters: Number of Hidden Layers: 10,number of neurons: 10,learning rate: 0.05
#
# Epoch 1/5
# 1719/1719 [==============================] - 7s 3ms/step - loss: 1.4201 - accuracy: 0.4234 - val_loss: 1.0461 - val_accuracy: 0.5376
# Epoch 2/5
# 1719/1719 [==============================] - 5s 3ms/step - loss: 1.2816 - accuracy: 0.4799 - val_loss: 1.8736 - val_accuracy: 0.2042
# Epoch 3/5
# 1719/1719 [==============================] - 5s 3ms/step - loss: 1.6062 - accuracy: 0.3345 - val_loss: 1.9463 - val_accuracy: 0.2068
# Epoch 4/5
# 1719/1719 [==============================] - 5s 3ms/step - loss: 2.2220 - accuracy: 0.1241 - val_loss: 2.3070 - val_accuracy: 0.1024
# Epoch 5/5
# 1719/1719 [==============================] - 5s 3ms/step - loss: 2.3107 - accuracy: 0.1005 - val_loss: 2.3129 - val_accuracy: 0.0980
# Highest accuracy so far: 0.10045454651117325
# Parameters: Number of Hidden Layers: 10,number of neurons: 10,learning rate: 0.1
#
# Epoch 1/5
# 1719/1719 [==============================] - 8s 4ms/step - loss: 1.3653 - accuracy: 0.4896 - val_loss: 0.8579 - val_accuracy: 0.6724
# Epoch 2/5
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.6437 - accuracy: 0.7654 - val_loss: 0.5433 - val_accuracy: 0.8100
# Epoch 3/5
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.5216 - accuracy: 0.8133 - val_loss: 0.5172 - val_accuracy: 0.8210
# Epoch 4/5
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.4696 - accuracy: 0.8291 - val_loss: 0.4293 - val_accuracy: 0.8436
# Epoch 5/5
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.4335 - accuracy: 0.8423 - val_loss: 0.4529 - val_accuracy: 0.8416
# Highest accuracy so far: 0.8423454761505127
# Parameters: Number of Hidden Layers: 10,number of neurons: 50,learning rate: 0.01
#
# Epoch 1/5
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.8739 - accuracy: 0.6700 - val_loss: 0.6191 - val_accuracy: 0.7682
# Epoch 2/5
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.4914 - accuracy: 0.8209 - val_loss: 0.4067 - val_accuracy: 0.8524
# Epoch 3/5
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.4313 - accuracy: 0.8429 - val_loss: 0.4007 - val_accuracy: 0.8566
# Epoch 4/5
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.3969 - accuracy: 0.8540 - val_loss: 0.3776 - val_accuracy: 0.8626
# Epoch 5/5
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.3743 - accuracy: 0.8644 - val_loss: 0.4020 - val_accuracy: 0.8560
# Highest accuracy so far: 0.8644363880157471
# Parameters: Number of Hidden Layers: 10,number of neurons: 50,learning rate: 0.05
#
# Epoch 1/5
# 1719/1719 [==============================] - 9s 4ms/step - loss: 0.9382 - accuracy: 0.6267 - val_loss: 0.5589 - val_accuracy: 0.7808
# Epoch 2/5
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.5224 - accuracy: 0.8127 - val_loss: 0.4495 - val_accuracy: 0.8398
# Epoch 3/5
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.4484 - accuracy: 0.8382 - val_loss: 0.4154 - val_accuracy: 0.8544
# Epoch 4/5
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.4165 - accuracy: 0.8492 - val_loss: 0.4084 - val_accuracy: 0.8588
# Epoch 5/5
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.3930 - accuracy: 0.8573 - val_loss: 0.4035 - val_accuracy: 0.8554
# Highest accuracy so far: 0.857345461845398
# Parameters: Number of Hidden Layers: 10,number of neurons: 50,learning rate: 0.1
#
# Epoch 1/5
# 1719/1719 [==============================] - 11s 6ms/step - loss: 1.4070 - accuracy: 0.4876 - val_loss: 0.7439 - val_accuracy: 0.7244
# Epoch 2/5
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.6319 - accuracy: 0.7679 - val_loss: 0.5097 - val_accuracy: 0.8264
# Epoch 3/5
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.4956 - accuracy: 0.8206 - val_loss: 0.4375 - val_accuracy: 0.8514
# Epoch 4/5
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.4332 - accuracy: 0.8415 - val_loss: 0.4199 - val_accuracy: 0.8498
# Epoch 5/5
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.3954 - accuracy: 0.8551 - val_loss: 0.4599 - val_accuracy: 0.8338
# Highest accuracy so far: 0.8551090955734253
# Parameters: Number of Hidden Layers: 10,number of neurons: 100,learning rate: 0.01
#
# Epoch 1/5
# 1719/1719 [==============================] - 11s 6ms/step - loss: 0.8264 - accuracy: 0.6849 - val_loss: 0.5489 - val_accuracy: 0.8118
# Epoch 2/5
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.4626 - accuracy: 0.8312 - val_loss: 0.4473 - val_accuracy: 0.8430
# Epoch 3/5
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.4072 - accuracy: 0.8520 - val_loss: 0.3691 - val_accuracy: 0.8736
# Epoch 4/5
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.3726 - accuracy: 0.8656 - val_loss: 0.3631 - val_accuracy: 0.8704
# Epoch 5/5
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.3513 - accuracy: 0.8707 - val_loss: 0.3846 - val_accuracy: 0.8686
# Highest accuracy so far: 0.8706727027893066
# Parameters: Number of Hidden Layers: 10,number of neurons: 100,learning rate: 0.05
#
# Epoch 1/5
# 1719/1719 [==============================] - 10s 5ms/step - loss: 0.8748 - accuracy: 0.6571 - val_loss: 0.5866 - val_accuracy: 0.7944
# Epoch 2/5
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.4953 - accuracy: 0.8188 - val_loss: 0.4780 - val_accuracy: 0.8282
# Epoch 3/5
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.4304 - accuracy: 0.8428 - val_loss: 0.4396 - val_accuracy: 0.8378
# Epoch 4/5
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.3935 - accuracy: 0.8571 - val_loss: 0.3813 - val_accuracy: 0.8640
# Epoch 5/5
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.3695 - accuracy: 0.8650 - val_loss: 0.3790 - val_accuracy: 0.8650
# Highest accuracy so far: 0.8649636507034302
# Parameters: Number of Hidden Layers: 10,number of neurons: 100,learning rate: 0.1
#
# Model: "sequential_29"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_29 (Flatten)        (None, 784)               0
#
#  dense_172 (Dense)           (None, 100)               78500
#
#  dense_173 (Dense)           (None, 100)               10100
#
#  dense_174 (Dense)           (None, 100)               10100
#
#  dense_175 (Dense)           (None, 100)               10100
#
#  dense_176 (Dense)           (None, 100)               10100
#
#  dense_177 (Dense)           (None, 100)               10100
#
#  dense_178 (Dense)           (None, 100)               10100
#
#  dense_179 (Dense)           (None, 100)               10100
#
#  dense_180 (Dense)           (None, 100)               10100
#
#  dense_181 (Dense)           (None, 100)               10100
#
#  dense_182 (Dense)           (None, 10)                1010
#
# =================================================================
# Total params: 170,410
# Trainable params: 170,410
# Non-trainable params: 0
# _________________________________________________________________
# None
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.
